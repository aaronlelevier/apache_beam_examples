# %%
import tensorflow_data_validation as tfdv

# %%
path = '/Users/aaron/tfx/pipelines/mnist/StatisticsGen/output/2/train/stats_tfrecord'

stats = tfdv.load_statistics(path)
# Out:
# WARNING:tensorflow:From /Users/aaron/Documents/github/tfx/venv/lib/python2.7/site-packages/tensorflow_data_validation/utils/stats_gen_lib.py:328: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
tfdv.visualize_statistics(stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.contentWindow.document.write(facets_html);
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
schema = tfdv.infer_schema(stats)
tfdv.display_schema(schema=schema)
# Out:
#                Type  Presence Valency Domain
# Feature name
# 'image_raw'   BYTES  required              -
# 'depth'         INT  required              -
# 'height'        INT  required              -
# 'width'         INT  required              -
# 'label'         INT  required              -

# %%
# eval dataset

# %%
eval_path = '/Users/aaron/tfx/pipelines/mnist/StatisticsGen/output/2/eval/stats_tfrecord'

eval_stats = tfdv.load_statistics(eval_path)

tfdv.visualize_statistics(eval_stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.contentWindow.document.write(facets_html);
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
train_stats = stats

# Compare evaluation data with training data
tfdv.visualize_statistics(lhs_statistics=eval_stats, rhs_statistics=train_stats,
                          lhs_name='EVAL_DATASET', rhs_name='TRAIN_DATASET')
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.contentWindow.document.write(facets_html);
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
anomalies = tfdv.validate_statistics(statistics=eval_stats, schema=schema)
tfdv.display_anomalies(anomalies)
# Out:
# <h4 style="color:green;">No anomalies found.</h4>

# %%
# check anomalies.pbtxt

# %%
from tfx.utils import io_utils
from tensorflow_metadata.proto.v0 import anomalies_pb2

# %%
path = '/Users/aaron/tfx/pipelines/mnist/ExampleValidator/output/4/anomalies.pbtxt'

anomalies = io_utils.parse_pbtxt_file(
        path,
        anomalies_pb2.Anomalies())

anomalies
# Out:
# baseline {
#   feature {
#     name: "image_raw"
#     value_count {
#       min: 1
#       max: 1
#     }
#     type: BYTES
#     presence {
#       min_fraction: 1.0
#       min_count: 1
#     }
#   }
#   feature {
#     name: "depth"
#     value_count {
#       min: 1
#       max: 1
#     }
#     type: INT
#     bool_domain {
#     }
#     presence {
#       min_fraction: 1.0
#       min_count: 1
#     }
#   }
#   feature {
#     name: "height"
#     value_count {
#       min: 1
#       max: 1
#     }
#     type: INT
#     presence {
#       min_fraction: 1.0
#       min_count: 1
#     }
#   }
#   feature {
#     name: "width"
#     value_count {
#       min: 1
#       max: 1
#     }
#     type: INT
#     presence {
#       min_fraction: 1.0
#       min_count: 1
#     }
#   }
#   feature {
#     name: "label"
#     value_count {
#       min: 1
#       max: 1
#     }
#     type: INT
#     presence {
#       min_fraction: 1.0
#       min_count: 1
#     }
#   }
# }
# ...

# %%
anomalies.anomaly_info
# Out:
# {}
